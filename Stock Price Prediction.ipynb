# %%
# importing libraries into python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
import seaborn as sns
# %matplotlib inline

# %%
#importing file from folder
dataset = pd.read_csv('1613615-Stock_Price_data_set.csv')

# %%
dataset
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
dataset.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
dataset['Date'] = pd.to_datetime(dataset.Date)

# %%
dataset['Date']
# Out:
# 0      2018-02-05
# 1      2018-02-06
# 2      2018-02-07
# 3      2018-02-08
# 4      2018-02-09
#           ...
# 1004   2022-01-31
# 1005   2022-02-01
# 1006   2022-02-02
# 1007   2022-02-03
# 1008   2022-02-04
# Name: Date, Length: 1009, dtype: datetime64[ns]

# %%
dataset.shape
# Out:
# (1009, 7)

# %%
dataset.drop('Adj Close',axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#         Date        Open        High         Low       Close    Volume
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  11896100
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  12595800
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998   8981500
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006   9306700
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  16906900

# %%
dataset.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1009 non-null   datetime64[ns]
#  1   Open    1009 non-null   float64
#  2   High    1009 non-null   float64
#  3   Low     1009 non-null   float64
#  4   Close   1009 non-null   float64
#  5   Volume  1009 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 47.4 KB

# %%
dataset.isna().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
dataset.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1009.000000  1009.000000  1009.000000  1009.000000  1.009000e+03
# mean    419.059673   425.320703   412.374044   419.000733  7.570685e+06
# std     108.537532   109.262960   107.555867   108.289999  5.465535e+06
# min     233.919998   250.649994   231.229996   233.880005  1.144000e+06
# 25%     331.489990   336.299988   326.000000   331.619995  4.091900e+06
# 50%     377.769989   383.010010   370.880005   378.670013  5.934500e+06
# 75%     509.130005   515.630005   502.529999   509.079987  9.322400e+06
# max     692.349976   700.989990   686.090027   691.690002  5.890430e+07

# %%
print(len(dataset))
# Out:
# 1009

# %%
dataset['Open'].plot(figsize=(25,9))
plt.tight_layout()

# %%
dataset['Close'].plot(figsize=(25,9))
plt.tight_layout()

# %%
dataset['High'].plot(figsize=(25,9))
plt.tight_layout()

# %%
dataset['Low'].plot(figsize=(25,9))
plt.tight_layout()

# %%
x = dataset[['Open','High','Low','Volume']]
y = dataset['Close']
print(x)
print(y)
# Out:
#             Open        High         Low    Volume
# 0     262.000000  267.899994  250.029999  11896100
# 1     247.699997  266.700012  245.000000  12595800
# 2     266.579987  272.450012  264.329987   8981500
# 3     267.079987  267.619995  250.000000   9306700
# 4     253.850006  255.800003  236.110001  16906900
# ...          ...         ...         ...       ...
# 1004  401.970001  427.700012  398.200012  20047500
# 1005  432.959991  458.480011  425.540009  22542300
# 1006  448.250000  451.980011  426.480011  14346000
# 1007  421.440002  429.260010  404.279999   9905200
# 1008  407.309998  412.769989  396.640015   7782400
#
# [1009 rows x 4 columns]
# 0       254.259995
# 1       265.720001
# 2       264.559998
# 3       250.100006
# 4       249.470001
#            ...
# 1004    427.140015
# 1005    457.130005
# 1006    429.480011
# 1007    405.600006
# 1008    410.170013
# Name: Close, Length: 1009, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.12,random_state =1)

# %%
x_train.shape
# Out:
# (887, 4)

# %%
x_test.shape
# Out:
# (122, 4)

# %%
y_train.shape
# Out:
# (887,)

# %%
y_test.shape
# Out:
# (122,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [-6.14118908e-01  8.20876246e-01  7.92813863e-01  5.95552786e-08]

# %%
print(regressor.intercept_)
# Out:
# -0.1458010006295467

# %%
predicted=regressor.predict(x_test)

# %%
print(x_test)
# Out:
#            Open        High         Low    Volume
# 986  599.909973  600.409973  581.599976   4393100
# 923  606.940002  640.390015  606.890015   9534300
# 293  369.000000  369.799988  364.660004   3905500
# 555  444.769989  447.000000  425.600006  23177600
# 582  417.459991  420.299988  411.850006   5254900
# ..          ...         ...         ...       ...
# 791  505.660004  518.000000  504.399994   3330000
# 120  366.850006  367.000000  351.649994   8949500
# 368  310.510010  319.989990  307.250000  11961800
# 938  673.760010  676.489990  662.770020   2904800
# 768  539.799988  556.849976  539.070007   3245000
#
# [122 rows x 4 columns]

# %%
predicted.shape
# Out:
# (122,)

# %%
dframe=pd.DataFrame(y_test,predicted)

# %%
dfr=pd.DataFrame({'Actual':y_test,'predicted Price':predicted})

# %%
print(dfr)
# Out:
#          Actual  predicted Price
# 986  591.150024       585.662582
# 923  634.809998       634.520454
# 293  365.489990       366.144447
# 555  433.829987       432.446154
# 582  419.730011       415.331752
# ..          ...              ...
# 791  513.950012       514.626351
# 120  355.209991       355.152236
# 368  317.940002       316.140760
# 938  668.520020       667.026256
# 768  553.409973       553.033169
#
# [122 rows x 2 columns]

# %%
dfr.head(50)
# Out:
#          Actual  predicted Price
# 986  591.150024       585.662582
# 923  634.809998       634.520454
# 293  365.489990       366.144447
# 555  433.829987       432.446154
# 582  419.730011       415.331752
# 248  339.500000       343.816026
# 718  501.089996       500.634004
# 673  534.659973       531.557515
# 329  349.190002       347.740142
# 49   336.059998       334.075132
# 708  485.000000       481.520070
# 142  368.489990       364.310818
# 948  655.989990       656.478573
# 250  351.339996       349.531916
# 535  360.269989       357.794729
# 133  326.399994       325.319120
# 104  398.390015       396.123196
# 6    258.269989       258.770754
# 422  267.529999       266.646692
# 679  541.940002       541.862611
# 976  593.739990       598.015773
# 484  339.260010       340.478358
# 433  271.500000       271.262894
# 27   321.089996       319.422635
# 389  296.929993       295.690962
# 119  363.089996       363.103780
# 108  418.649994       417.929633
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
regressor.score(x_test,y_test)
# Out:
# 0.9989268769946091

# %%
import math

# %%
print('Mean Absolute Error :',metrics.mean_absolute_error(y_test,predicted))
# Out:
# Mean Absolute Error : 2.571035316444718

# %%
print('Mean Squared Error :',metrics.mean_squared_error(y_test,predicted))
# Out:
# Mean Squared Error : 13.74054239173354

# %%
print('Root Mean Square Error :',math.sqrt(metrics.mean_absolute_error(y_test,predicted)))
# Out:
# Root Mean Square Error : 1.603444828001487

# %%
graph=dfr.tail(10)

# %%
graph.plot(kind='bar')
plt.tight_layout()
